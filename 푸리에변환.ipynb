# %% [markdown]
# <a href="https://colab.research.google.com/github/hide-squid/high-school-project-1/blob/main/%ED%91%B8%EB%A6%AC%EC%97%90%EB%B3%80%ED%99%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# 시간 범위 설정
t = np.linspace(0, 1, 500, endpoint=False)
# 원래의 신호(시간 영역)
f = np.sin(50 * 2 * np.pi * t) + 0.5 * np.sin(80 * 2 * np.pi * t)

# 푸리에 변환 (주파수 영역으로 변환)
F = np.fft.fft(f)

# 주파수 축 생성
freq = np.fft.fftfreq(t.shape[-1])

# 역푸리에 변환 (다시 시간 영역으로 변환)
f_reconstructed = np.fft.ifft(F)

# 원래 신호 플롯
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.plot(t, f)
plt.title("Original Signal (Time Domain)")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")

# 푸리에 변환된 신호 플롯 (주파수 영역)
plt.subplot(2, 2, 2)
plt.plot(freq, np.abs(F))
plt.title("Fourier Transform (Frequency Domain)")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Magnitude")

# 역푸리에 변환된 신호 플롯 (시간 영역)
plt.subplot(2, 2, 3)
plt.plot(t, f_reconstructed.real)
plt.title("Reconstructed Signal (Time Domain)")
plt.xlabel("Time [s]")
plt.ylabel("Amplitude")

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 시간 범위 설정
t = np.linspace(0, 1, 500, endpoint=False)
# 원래의 신호(시간 영역)
f = np.sin(50 * 2 * np.pi * t) + 0.5 * np.sin(80 * 2 * np.pi * t)

# 푸리에 변환 (주파수 영역으로 변환)
F = np.fft.fft(f)

# 주파수 축 생성
freq = np.fft.fftfreq(t.shape[-1])

# 역푸리에 변환 (다시 시간 영역으로 변환)
f_reconstructed = np.fft.ifft(F)

# 원래 신호 플롯
plt.figure(figsize=(12, 6))

plt.subplot(2, 2, 1)
plt.plot(t, f)
plt.title("원래 신호 (시간 영역)")
plt.xlabel("시간 [s]")
plt.ylabel("진폭")

# 푸리에 변환된 신호 플롯 (주파수 영역)
plt.subplot(2, 2, 2)
plt.plot(freq, np.abs(F))
plt.title("푸리에 변환 (주파수 영역)")
plt.xlabel("주파수 [Hz]")
plt.ylabel("크기")

# 역푸리에 변환된 신호 플롯 (시간 영역)
plt.subplot(2, 2, 3)
plt.plot(t, f_reconstructed.real)
plt.title("복원된 신호 (시간 영역)")
plt.xlabel("시간 [s]")
plt.ylabel("진폭")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-3-7e2138c5325c>:41: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.tight_layout()
# <ipython-input-3-7e2138c5325c>:41: UserWarning: Glyph 44036 (\N{HANGUL SYLLABLE GAN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-3-7e2138c5325c>:41: UserWarning: Glyph 51652 (\N{HANGUL SYLLABLE JIN}) missing from current font.
#   plt.tight_layout()
# <ipython-input-3-7e2138c5325c>:41: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-3-7e2138c5325c>:41: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-3-7e2138c5325c>:41: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   plt.tight_layout()
# <ipython-input-3-7e2138c5325c>:41: UserWarning: Glyph 49888 (\N{HANGUL SYLLABLE SIN}) missing from current font.
#   plt.tight_layout()
# ...

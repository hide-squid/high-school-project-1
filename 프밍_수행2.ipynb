# %% [markdown]
# <a href="https://colab.research.google.com/github/hide-squid/high-school-project-1/blob/main/%ED%94%84%EB%B0%8D_%EC%88%98%ED%96%892.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#-------------------------------------------------------------------------------------------------------------
def movie1(list_1): #메인에서 신호가 온다면
    i = 0  #i변수에 0 선언
    MVN1 = input("영화 제목 입력: ") #MVN1변수에 영화제목 입력 받음
    MVRV = input("영화 리뷰 입력: ") #MVRV변수에 영화리뷰 입력 받음
    list_2 = [] #list_2변수에 1차원 배열 선언
    list_2.append(MVN1) #list_2의 1차원 배열에 MVN1값 추가
    list_2.append(MVRV) #list_2의 1차원 배열에 MVRV값 추가
    list_1.append(list_2) #list_1의 1차원 배열에 list_2의 1차원 배열을 넣어 2차원 배열 생성
    print("저장되었습니다.") #저장되었습니다 출력
    print("") #들여쓰기
    return list_1 #2차원 배열 돌려내보내기
#==============================================================================================================
def movie2(list_1): #메인에서 신호가 온다면(asdf값과 함께)
    a = 0 #a변수에 0 선언
    index = 0 #index변수에 0 선언
    MVN2 = input("영화 제목 입력 : ") #MVN2변수에 영화제목 입력
    for a in list_1: #list_1의 길이만큼 반복
        if MVN2 in a: #만약 MVN2가 문자열 배열에 있으면
            print("영화 리뷰: "+list_1[index][1]) #영화리뷰 출력(세로 index번째와 가로 1번째에 있는 값 출력)
        index = index + 1 #index변수 1씩 증가
    print("") #들여쓰기

#----------------------------------------------------------------------------------------------------------------
#<<<<<<<메인>>>>>>>>
print("----<<영화 리뷰 맛집>>----") #처음 실행했을때 영화 리뷰 맛집 출력
list_1 = [] #list_1변수에 1차원 배열 선언
while 1:   #무한반복 (=while True:)
    num = int(input("1.영화 리뷰 적기 2.영화 리뷰 알아보기 3.끝 :")) #num변수에 1, 2, 3의 값을 사용자에게 받는다.
    if num == 1: #num이 만약 1이라면
        asdf = movie1(list_1) #asdf변수에 저장(movie1함수 호출하고 돌아온 값)
    elif num == 2: #num이 만약 2라면
        movie2(asdf) #movie2함수 호출(asdf의 값과 함께)
    elif num == 3: #num이 만약 3이라면
        break #무한반복을 멈춘다.
    else: #다른 숫자, 문자가 들어오면
        print("ERrOr") #ERrOr 출력
        continue #다시
#-----------------------------------------------------------------------------------------------------------------
# Out:
# ----<<영화 리뷰 맛집>>----
# 1.영화 리뷰 적기 2.영화 리뷰 알아보기 3.끝 :3
